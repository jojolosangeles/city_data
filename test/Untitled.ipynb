# %%
import pandas as pd
all_areas = pd.read_csv('expected/all_areas.csv')
all_areas
# Out:
#         Unnamed: 0 Date Occurred  Time Occurred    Area Name  Victim Age  \
# 0                0    11/04/2010           1345      Central        20.0
# 1                1    08/10/2010           1900  77th Street        31.0
# 2                2    06/09/2010           1925      Pacific        40.0
# 3                3    04/06/2010           1445      Topanga        51.0
# 4                4    05/23/2010           1805    Southwest        32.0
# 5                5    09/02/2010           1520     Foothill        45.0
# 6                6    10/27/2010           1910  77th Street        61.0
# 7                7    09/30/2010            540  77th Street        70.0
# 8                8    11/19/2010           1440  77th Street         NaN
# 9                9    02/21/2010            300       Newton        44.0
# 10              10    09/01/2010           1530    Hollywood         NaN
# 11              11    03/11/2010           1840  77th Street        55.0
# ...

# %%
mf = all_areas[(all_areas['Victim Sex'] == 'M') | (all_areas['Victim Sex'] == 'F')]
mf
# Out:
#         Unnamed: 0 Date Occurred  Time Occurred    Area Name  Victim Age  \
# 0                0    11/04/2010           1345      Central        20.0
# 1                1    08/10/2010           1900  77th Street        31.0
# 2                2    06/09/2010           1925      Pacific        40.0
# 3                3    04/06/2010           1445      Topanga        51.0
# 4                4    05/23/2010           1805    Southwest        32.0
# 5                5    09/02/2010           1520     Foothill        45.0
# 6                6    10/27/2010           1910  77th Street        61.0
# 7                7    09/30/2010            540  77th Street        70.0
# 8                8    11/19/2010           1440  77th Street         NaN
# 9                9    02/21/2010            300       Newton        44.0
# 10              10    09/01/2010           1530    Hollywood         NaN
# 11              11    03/11/2010           1840  77th Street        55.0
# ...

# %%
mfg = mf.groupby('Victim Sex')

# %%
mfg.describe()
# Out:
#                 Hour                                                    \
#                count       mean       std  min   25%   50%   75%   max
# Victim Sex
# F           172171.0  13.497761  5.568484  0.0  10.0  14.0  18.0  23.0
# M           265398.0  13.236562  6.159025  0.0   9.0  14.0  18.0  23.0
#
#            Time Occurred                ...   Weekday           Year  \
#                    count         mean   ...       75%  max     count
# Victim Sex                              ...
# F               172171.0  1373.780346   ...       5.0  6.0  172171.0
# M               265398.0  1347.730544   ...       5.0  6.0  265398.0
#
#
#                    mean       std     min     25%     50%     75%     max
# Victim Sex
# F           2014.227861  2.608647  2010.0  2012.0  2014.0  2017.0  2019.0
# M           2014.245394  2.613072  2010.0  2012.0  2014.0  2017.0  2019.0
#
# [2 rows x 48 columns]
